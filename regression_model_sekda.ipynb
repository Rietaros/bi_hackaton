# %%
import pandas as pd

from sklearn.svm import SVR #SVR
from sklearn.tree import DecisionTreeRegressor #decisiontreeregressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split as holdout

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

df = pd.read_csv("data_regresi_kabkot_new.csv")

df.tail()
# Out:
#                         kab  bps_kab              prov  total_pnddk  jmlh_kk  \
# 477                 MAYBRAT     9110  PAPUA BARAT DAYA        45064    13904
# 478          KOTA TANGERANG     3671            BANTEN      1899514   611828
# 479  KOTA TANGERANG SELATAN     3674            BANTEN      1404785   443478
# 480                  SORONG     9107  PAPUA BARAT DAYA       125217    39628
# 481          SORONG SELATAN     9106  PAPUA BARAT DAYA        52854    15331
#
#      luas_wilayah_gis  luas_wil_dukcapil   pnddk_per_m  usia_20sd24  \
# 477      16070.917279             3121.0      2.804071         5240
# 478        184.637437              181.0  10287.805287       149709
# 479        168.257837              164.0   8349.001914       114020
# 480       4461.327438             3305.0     28.067207        11981
# 481       2267.453017             2138.0     23.309855         5079
#
#      usia_25sd29  ...  loan_konstruksi_112023  \
# 477         4718  ...            5.080009e+03
# 478       149832  ...            7.758236e+06
# 479       114278  ...            5.533247e+06
# 480        11051  ...            3.433313e+03
# 481         4903  ...            4.676331e+04
#
#      loan_pengadaan_air_pengelolaan_sampah_limbah_daur_ulang_112023  \
# 477                                         138.635117
# 478                                      657727.235269
# 479                                       75420.226355
# 480                                                NaN
# 481                                         599.764817
#
#      loan_pengadaan_listrik_dan_gas_112023  loan_jasa_pendidikan_112023  \
# 477                                    NaN                          NaN
# 478                           75639.903522                481610.684155
# 479                           19209.190628                433085.049139
# 480                                    NaN                          NaN
# 481                           16657.786560                    94.859017
#
#      loan_adm_pemerintahan_pertahanan_jaminan_sosial_wajib_112023  \
# 477                                                NaN
# 478                                        4989.738409
# 479                                        1504.529303
# 480                                                NaN
# 481                                        2972.641397
#
#      loan_kendaraan_bermotor_112023  loan_flat_dan_apartemen_112023  \
# 477                    8.560438e+02                             NaN
# 478                    1.767073e+06                    1.406947e+06
# 479                    1.501031e+06                    1.323823e+06
# 480                    1.975556e+02                             NaN
# 481                    7.025488e+02                    2.427738e+02
#
#      loan_lainnya_112023  loan_rumah_tinggal_112023  loan_ruko_rukan_112023
# 477         4.598616e+05               1.194103e+03                     NaN
# 478         1.270035e+07               1.720047e+07           721056.119084
# 479         8.435109e+06               1.334467e+07           475616.298574
# 480         1.289779e+05               4.325473e+02              230.539882
# 481         1.175905e+06               5.061383e+04             5430.548995
#
# [5 rows x 68 columns]

# %%
df = df.set_index('bps_kab')
df.fillna(0, inplace=True)

df.head()
# Out:
#                    kab  prov  total_pnddk  jmlh_kk  luas_wilayah_gis  \
# bps_kab
# 1103      ACEH SELATAN  ACEH       235525    71087       5512.797387
# 1104     ACEH TENGGARA  ACEH       229368    66821       4769.008409
# 1105        ACEH TIMUR  ACEH       445666   129000       2854.349276
# 1106       ACEH TENGAH  ACEH       223932    68405       2947.586694
# 1107        ACEH BARAT  ACEH       201719    64793       3029.044454
#
#          luas_wil_dukcapil  pnddk_per_m  usia_20sd24  usia_25sd29  \
# bps_kab
# 1103                3082.0    42.723319        22196        20067
# 1104                2689.0    48.095533        20515        18875
# 1105                1687.0   156.135762        39581        35915
# 1106                2373.0    75.971302        20240        17611
# 1107                 785.0    66.594929        15937        15870
#
#          usia_30sd34  ...  loan_konstruksi_112023  \
# bps_kab               ...
# 1103           17778  ...            12322.221599
# 1104           16794  ...            37819.865707
# 1105           35131  ...            22587.810209
# 1106           16667  ...            63696.845064
# 1107           15611  ...           120487.004312
#
#          loan_pengadaan_air_pengelolaan_sampah_limbah_daur_ulang_112023  \
# bps_kab
# 1103                                            740.877033
# 1104                                              0.000000
# 1105                                             95.866898
# 1106                                            677.286920
# 1107                                            284.222388
#
#          loan_pengadaan_listrik_dan_gas_112023  loan_jasa_pendidikan_112023  \
# bps_kab
# 1103                               1415.134618                   290.253952
# 1104                                709.530521                  4136.377387
# 1105                                597.775976                  1426.485101
# 1106                                867.661958                  2224.478823
# 1107                               2242.126465                  5750.422407
#
#          loan_adm_pemerintahan_pertahanan_jaminan_sosial_wajib_112023  \
# bps_kab
# 1103                                              0.000000
# 1104                                              0.000000
# 1105                                              0.000000
# 1106                                           2583.834017
# 1107                                            144.468785
#
#          loan_kendaraan_bermotor_112023  loan_flat_dan_apartemen_112023  \
# bps_kab
# 1103                      133949.080727                     1023.619668
# 1104                       35234.706758                      174.470725
# 1105                      142163.192959                     1096.653834
# 1106                      224384.455189                    20674.816839
# 1107                       59588.837995                     4177.637541
#
#          loan_lainnya_112023  loan_rumah_tinggal_112023  \
# bps_kab
# 1103            1.019418e+06              141570.419631
# 1104            1.118972e+06               87924.990008
# 1105            1.201709e+06              117016.670484
# 1106            1.768471e+06              804061.766769
# 1107            1.246814e+06               90114.009674
#
#          loan_ruko_rukan_112023
# bps_kab
# 1103                 266.112538
# 1104                   0.000000
# 1105                2822.082942
# 1106                3195.629371
# 1107                 461.554773
#
# [5 rows x 67 columns]

# %%
target = ['simpanan_giro_nominal_112023',
'simpanan_berjangka_nominal_112023',
'simpanan_tabungan_nominal_112023',
'loan_industri_pengolahan_112023',
'loan_pertambangan_penggalian_112023',
'loan_penyedia_akm_makan_minum_112023',
'loan_jasa_lainnya_112023',
'loan_jasa_perusahaan_112023',
'loan_kesehatan_dan_kegiatan_lain_112023',
'loan_pertanian_kehutanan_perikanan_112023',
'loan_keuangan_dan_asuransi_112023',
'loan_perdagangan_besar_ecer_reparasi_mobil_motor_112023',
'loan_real_estate_112023',
'loan_transportasi_pergudangan_112023',
'loan_informasi_komunikasi_112023',
'loan_konstruksi_112023',
'loan_pengadaan_air_pengelolaan_sampah_limbah_daur_ulang_112023',
'loan_pengadaan_listrik_dan_gas_112023',
'loan_jasa_pendidikan_112023',
'loan_adm_pemerintahan_pertahanan_jaminan_sosial_wajib_112023',
'loan_kendaraan_bermotor_112023',
'loan_flat_dan_apartemen_112023',
'loan_lainnya_112023',
'loan_rumah_tinggal_112023',
'loan_ruko_rukan_112023']

# %%
x = df.drop([
    'kab',
    'prov',
    'simpanan_giro_nominal_112023',
'simpanan_berjangka_nominal_112023',
'simpanan_tabungan_nominal_112023',
'loan_industri_pengolahan_112023',
'loan_pertambangan_penggalian_112023',
'loan_penyedia_akm_makan_minum_112023',
'loan_jasa_lainnya_112023',
'loan_jasa_perusahaan_112023',
'loan_kesehatan_dan_kegiatan_lain_112023',
'loan_pertanian_kehutanan_perikanan_112023',
'loan_keuangan_dan_asuransi_112023',
'loan_perdagangan_besar_ecer_reparasi_mobil_motor_112023',
'loan_real_estate_112023',
'loan_transportasi_pergudangan_112023',
'loan_informasi_komunikasi_112023',
'loan_konstruksi_112023',
'loan_pengadaan_air_pengelolaan_sampah_limbah_daur_ulang_112023',
'loan_pengadaan_listrik_dan_gas_112023',
'loan_jasa_pendidikan_112023',
'loan_adm_pemerintahan_pertahanan_jaminan_sosial_wajib_112023',
'loan_kendaraan_bermotor_112023',
'loan_flat_dan_apartemen_112023',
'loan_lainnya_112023',
'loan_rumah_tinggal_112023',
'loan_ruko_rukan_112023'], axis = 1) #Prediktor
y = df['loan_industri_pengolahan_112023'] #Label

# %%
y.head()
# Out:
# bps_kab
# 1103    139585.617459
# 1104     35737.247652
# 1105     71039.176447
# 1106     75519.829348
# 1107     71361.577033
# Name: loan_industri_pengolahan_112023, dtype: float64

# %%
X_train, X_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=5)

# %%
svr = SVR()
dt = DecisionTreeRegressor()
rf = RandomForestRegressor()
mlp = MLPRegressor(hidden_layer_sizes=(100,50,30,15,10, 10))
lr = LinearRegression()
knn = KNeighborsRegressor()


#train
svr.fit(X_train, y_train)
dt.fit(X_train, y_train)
rf.fit(X_train, y_train)
mlp.fit(X_train, y_train)
lr.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# KNeighborsRegressor()

# %%
import numpy as np

y_pred_svr = svr.predict(X_test)
y_pred_dt = dt.predict(X_test)
y_pred_rf = rf.predict(X_test)
y_pred_mlp = mlp.predict(X_test)
y_pred_lr = lr.predict(X_test)
y_pred_knn = knn.predict(X_test)

print("SVR")
print("MSE: ",mean_squared_error(y_test,y_pred_svr))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_svr)))
print("R2: ",r2_score(y_test,y_pred_svr))
print("")

print("Decission Tree Regression")
print("MSE: ",mean_squared_error(y_test,y_pred_dt))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_dt)))
print("R2: ",r2_score(y_test,y_pred_dt))
print("")

print("Random Forest Regression")
print("MSE: ",mean_squared_error(y_test,y_pred_rf))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
print("R2: ",r2_score(y_test,y_pred_rf))
print("")

print("MLP Regression")
print("MSE: ",mean_squared_error(y_test,y_pred_mlp))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_mlp)))
print("R2: ",r2_score(y_test,y_pred_mlp))
print("")

print("Linear Regression")
print("MSE: ",mean_squared_error(y_test,y_pred_lr))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
print("R2: ",r2_score(y_test,y_pred_lr))
print("")

print("KNN")
print("MSE: ",mean_squared_error(y_test,y_pred_knn))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_knn)))
print("R2: ",r2_score(y_test,y_pred_knn))
print("")

#LAG 1
# SVR
# MSE:  46354.59285912892
# RMSE:  215.30116780716477
# R2:  -6.705221132195093

# Decission Tree Regression
# MSE:  6037.452380952381
# RMSE:  77.70104491544744
# R2:  -0.0035662660593165363

# Random Forest Regression
# MSE:  6794.314012950828
# RMSE:  82.42762894170151
# R2:  -0.12937443050042874

# MLP Regression
# MSE:  4084.473084060486
# RMSE:  63.90988252266222
# R2:  0.3210647234713663

# Linear Regression
# MSE:  2394.832091799372
# RMSE:  48.93702168909927
# R2:  0.6019227070364079

# KNN
# MSE:  8284.283809523808
# RMSE:  91.01804112110855
# R2:  -0.3770423756763426

#LAG3
# SVR
# MSE:  43852.88402276194
# RMSE:  209.41080206799728
# R2:  -6.052630152114012

# Decission Tree Regression
# MSE:  4160.475
# RMSE:  64.50174416246432
# R2:  0.33089254935008694

# Random Forest Regression
# MSE:  3547.062980000001
# RMSE:  59.557224414843255
# R2:  0.42954439869426353

# MLP Regression
# MSE:  10022.044968423888
# RMSE:  100.11016416140716
# R2:  -0.6117931147575446

# Linear Regression
# MSE:  2102.168584776421
# RMSE:  45.8494120439556
# R2:  0.6619192129273492

# KNN
# MSE:  5969.379999999999
# RMSE:  77.26176285848
# R2:  0.03997581195402522
# Out:
# SVR
# MSE:  222978500152007.97
# RMSE:  14932464.63756094
# R2:  -0.09595512013717866
#
# Decission Tree Regression
# MSE:  165246308545011.62
# RMSE:  12854816.550422322
# R2:  0.18780269034811414
#
# Random Forest Regression
# MSE:  80419592683423.53
# RMSE:  8967697.178396666
# R2:  0.60473200644609
#
# MLP Regression
# MSE:  90245988161989.62
# RMSE:  9499788.848284451
# R2:  0.556434576739254
#
# Linear Regression
# MSE:  114980233776330.98
# RMSE:  10722883.650228187
# R2:  0.434864007804185
#
# KNN
# MSE:  113364343735800.47
# RMSE:  10647269.308879176
# R2:  0.4428062217947303

# %%
import pickle
with open("my_model_mlp_simpanan_giro_nominal_112023.pkl", "wb") as f:
  pickle.dump(mlp, f)

# %%
for xx in target:
    y = df[xx] 
    X_train, X_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=5)
    mlp = MLPRegressor(hidden_layer_sizes=(100,50,30,15,10, 10))
    
    mlp.fit(X_train, y_train)
    y_pred_mlp = mlp.predict(X_test)
    print("MLP Regression")
    print("Target: ", xx)
    print("MSE: ",mean_squared_error(y_test,y_pred_mlp))
    print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_mlp)))
    print("R2: ",r2_score(y_test,y_pred_mlp))
    print("")
    with open("my_model_"+xx+".pkl", "wb") as f:
      pickle.dump(mlp, f)
# Out:
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  simpanan_giro_nominal_112023
# MSE:  269801460942219.78
# RMSE:  16425634.263011575
# R2:  0.9270359560813188
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  simpanan_berjangka_nominal_112023
# MSE:  1051751139598474.9
# RMSE:  32430712.906109154
# R2:  0.771897091009599
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  simpanan_tabungan_nominal_112023
# MSE:  169650880319359.47
# RMSE:  13025009.801123355
# R2:  0.7187555917092279
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_industri_pengolahan_112023
# MSE:  89076446462846.7
# RMSE:  9438031.916816488
# R2:  0.5621829570203833
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_pertambangan_penggalian_112023
# MSE:  4941090619722.134
# RMSE:  2222856.4100548946
# R2:  0.6781935185221584
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_penyedia_akm_makan_minum_112023
# MSE:  756779104697.2303
# RMSE:  869930.5171663024
# R2:  0.5536765773259968
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_jasa_lainnya_112023
# MSE:  26992141981044.33
# RMSE:  5195396.229455875
# R2:  0.21673880753989738
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_jasa_perusahaan_112023
# MSE:  1994712053735.5918
# RMSE:  1412342.753631565
# R2:  0.29334822029151764
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_kesehatan_dan_kegiatan_lain_112023
# MSE:  41063629063.58643
# RMSE:  202641.62717365462
# R2:  0.791438171836222
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_pertanian_kehutanan_perikanan_112023
# MSE:  248448959513.27042
# RMSE:  498446.5462948564
# R2:  0.33081240175801563
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_keuangan_dan_asuransi_112023
# MSE:  5524575752300.95
# RMSE:  2350441.607932635
# R2:  0.9602161907468363
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_perdagangan_besar_ecer_reparasi_mobil_motor_112023
# MSE:  37699566776991.65
# RMSE:  6139997.294542698
# R2:  0.6363679190370588
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_real_estate_112023
# MSE:  2682181286046.6035
# RMSE:  1637736.6351298988
# R2:  0.9067777778345381
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_transportasi_pergudangan_112023
# MSE:  7634062899609.31
# RMSE:  2762980.7997178175
# R2:  0.6503321504746009
#
# MLP Regression
# Target:  loan_informasi_komunikasi_112023
# MSE:  45098063018636.85
# RMSE:  6715509.140685973
# R2:  -0.019713541598861184
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_konstruksi_112023
# MSE:  54648858415005.57
# RMSE:  7392486.619196924
# R2:  0.28180559278875783
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_pengadaan_air_pengelolaan_sampah_limbah_daur_ulang_112023
# MSE:  42089086962.267525
# RMSE:  205156.2501174837
# R2:  -0.22624362553207944
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_pengadaan_listrik_dan_gas_112023
# MSE:  16911953045443.281
# RMSE:  4112414.503116543
# R2:  -3.0129641392375417
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_jasa_pendidikan_112023
# MSE:  12091413843.817507
# RMSE:  109960.9650913337
# R2:  0.6100665661268514
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_adm_pemerintahan_pertahanan_jaminan_sosial_wajib_112023
# MSE:  585433835.2208583
# RMSE:  24195.740022178663
# R2:  -1.5239095160397893
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_kendaraan_bermotor_112023
# MSE:  591226404215.5664
# RMSE:  768912.4815059035
# R2:  0.1192669322134231
#
# MLP Regression
# Target:  loan_flat_dan_apartemen_112023
# MSE:  223335457545.6416
# RMSE:  472583.81007567496
# R2:  -0.03354338453669836
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_lainnya_112023
# MSE:  9615296792081.855
# RMSE:  3100854.2036158126
# R2:  0.75676876982865
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Regression
# Target:  loan_rumah_tinggal_112023
# MSE:  14340027579014.273
# RMSE:  3786822.8871990135
# R2:  0.6586866181597253
#
# MLP Regression
# Target:  loan_ruko_rukan_112023
# MSE:  41775741726.96378
# RMSE:  204391.14884691994
# R2:  -0.10718154975779104
# /Users/aries_fitriawan/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
df_kec = pd.read_csv("kecamatan_level_predict.csv")
df_kec.tail()
# Out:
#                 kab  bps_kab   prov               kec  bps_kec kmdgr_kec  \
# 7261  KOTA JAYAPURA     9471  PAPUA        MUARA TAMI  9471010  91.71.04
# 7262  KOTA JAYAPURA     9471  PAPUA           ABEPURA  9471020  91.71.03
# 7263  KOTA JAYAPURA     9471  PAPUA             HERAM  9471021  91.71.05
# 7264  KOTA JAYAPURA     9471  PAPUA  JAYAPURA SELATAN  9471030  91.71.02
# 7265  KOTA JAYAPURA     9471  PAPUA    JAYAPURA UTARA  9471040  91.71.01
#
#       total_pnddk  jmlh_kk  luas_wilayah_gis  luas_wil_dukcapil  ...  \
# 7261        22804     7198        437.416263              182.0  ...
# 7262       122111    40571        146.969959              147.0  ...
# 7263        61018    20304         66.932512               62.0  ...
# 7264       101744    32519         52.093972               51.0  ...
# 7265        94395    30260         62.416619               61.0  ...
#
#       popses_e  jmlh_kk_a1  jmlh_kk_a2  jmlh_kk_b  jmlh_kk_c1  jmlh_kk_c2  \
# 7261         0        3024        2473       1278         316          94
# 7262         0       17044       13945       7186        1787         529
# 7263         0        8530        6980       3593         895         266
# 7264         0       13659       11177       5761        1434         424
# 7265         0       12711       10401       5357        1334         396
#
#       jmlh_kk_d  jmlh_kk_e  mostses  avrg_income
# 7261         13          0        7      1961734
# 7262         80          0        7      1961734
# 7263         40          0        7      1961734
# 7264         64          0        7      1961734
# 7265         61          0        7      1961734
#
# [5 rows x 46 columns]

# %%
df_kec = df_kec.set_index('bps_kec')
df_kec.fillna(0, inplace=True)

df_kec.head()
# Out:
#               kab  bps_kab  prov              kec kmdgr_kec  total_pnddk  \
# bps_kec
# 1101010  SIMEULUE     1101  ACEH   TEUPAH SELATAN  11.09.07         9488
# 1101020  SIMEULUE     1101  ACEH   SIMEULUE TIMUR  11.09.04        27743
# 1101021  SIMEULUE     1101  ACEH     TEUPAH BARAT  11.09.03         8139
# 1101022  SIMEULUE     1101  ACEH    TEUPAH TENGAH  11.09.09         6826
# 1101030  SIMEULUE     1101  ACEH  SIMEULUE TENGAH  11.09.01         7581
#
#          jmlh_kk  luas_wilayah_gis  luas_wil_dukcapil  pnddk_per_m  ...  \
# bps_kec                                                             ...
# 1101010     2719        231.590978              213.0    40.968781  ...
# 1101020     7727        180.427496              164.0   153.762595  ...
# 1101021     2465        165.043407              164.0    49.314300  ...
# 1101022     2082         61.142501               62.0   111.640836  ...
# 1101030     2249        246.236413              252.0    30.787486  ...
#
#          popses_e  jmlh_kk_a1  jmlh_kk_a2  jmlh_kk_b  jmlh_kk_c1  jmlh_kk_c2  \
# bps_kec
# 1101010        83         132         417        933         811         208
# 1101020       244         382        1186       2640        2300         592
# 1101021        72         121         380        842         732         187
# 1101022        59         104         319        709         620         159
# 1101030        67         111         345        766         667         175
#
#          jmlh_kk_d  jmlh_kk_e  mostses  avrg_income
# bps_kec
# 1101010        144         74        5       813631
# 1101020        408        219        5       813631
# 1101021        132         71        5       813631
# 1101022        111         60        5       813631
# 1101030        122         63        5       813631
#
# [5 rows x 45 columns]

# %%
x = df_kec.drop([
  'kab','bps_kab','prov','kec','kmdgr_kec'], axis = 1).copy()
x1 = df_kec.drop([
  'kab','bps_kab','prov','kec','kmdgr_kec'], axis = 1).copy()

# %%
with open("my_model_mlp_simpanan_giro_nominal_112023.pkl", "rb") as f:
  mlp = pickle.load(f)

# %%
y_pred_mlp = mlp.predict(x)
x['pred_simpanan_giro_nominal_112023'] = y_pred_mlp
x.head()
# Out:
#          total_pnddk  jmlh_kk  luas_wilayah_gis  luas_wil_dukcapil  \
# bps_kec
# 1101010         9488     2719        231.590978              213.0
# 1101020        27743     7727        180.427496              164.0
# 1101021         8139     2465        165.043407              164.0
# 1101022         6826     2082         61.142501               62.0
# 1101030         7581     2249        246.236413              252.0
#
#          pnddk_per_m  usia_20sd24  usia_25sd29  usia_30sd34  usia_35sd39  \
# bps_kec
# 1101010    40.968781         1025          804          643          726
# 1101020   153.762595         2408         2036         1953         2317
# 1101021    49.314300          813          682          582          582
# 1101022   111.640836          598          518          508          564
# 1101030    30.787486          666          555          572          551
#
#          usia_40sd44  ...  jmlh_kk_a1  jmlh_kk_a2  jmlh_kk_b  jmlh_kk_c1  \
# bps_kec               ...
# 1101010          697  ...         132         417        933         811
# 1101020         2319  ...         382        1186       2640        2300
# 1101021          687  ...         121         380        842         732
# 1101022          608  ...         104         319        709         620
# 1101030          532  ...         111         345        766         667
#
#          jmlh_kk_c2  jmlh_kk_d  jmlh_kk_e  mostses  avrg_income  \
# bps_kec
# 1101010         208        144         74        5       813631
# 1101020         592        408        219        5       813631
# 1101021         187        132         71        5       813631
# 1101022         159        111         60        5       813631
# 1101030         175        122         63        5       813631
#
#          pred_simpanan_giro_nominal_112023
# bps_kec
# 1101010                       79956.930428
# 1101020                       75412.217595
# 1101021                       79963.568930
# 1101022                       79977.939999
# 1101030                       80157.720559
#
# [5 rows x 41 columns]

# %%
for xx in target:
    print(xx)
    with open("my_model_"+xx+".pkl", "rb") as f:
      mlp = pickle.load(f)
    
    y_pred_mlp = mlp.predict(x1)
    x['pred_'+xx] = y_pred_mlp
    print("pred_done")

x.head()
# Out:
# simpanan_giro_nominal_112023
# pred_done
# simpanan_berjangka_nominal_112023
# pred_done
# simpanan_tabungan_nominal_112023
# pred_done
# loan_industri_pengolahan_112023
# pred_done
# loan_pertambangan_penggalian_112023
# pred_done
# loan_penyedia_akm_makan_minum_112023
# pred_done
# loan_jasa_lainnya_112023
# pred_done
# loan_jasa_perusahaan_112023
# pred_done
# loan_kesehatan_dan_kegiatan_lain_112023
# pred_done
# loan_pertanian_kehutanan_perikanan_112023
# pred_done
# loan_keuangan_dan_asuransi_112023
# pred_done
# loan_perdagangan_besar_ecer_reparasi_mobil_motor_112023
# pred_done
# loan_real_estate_112023
# pred_done
# loan_transportasi_pergudangan_112023
# pred_done
# loan_informasi_komunikasi_112023
# pred_done
# loan_konstruksi_112023
# pred_done
# loan_pengadaan_air_pengelolaan_sampah_limbah_daur_ulang_112023
# pred_done
# loan_pengadaan_listrik_dan_gas_112023
# pred_done
# loan_jasa_pendidikan_112023
# pred_done
# loan_adm_pemerintahan_pertahanan_jaminan_sosial_wajib_112023
# pred_done
# loan_kendaraan_bermotor_112023
# pred_done
# loan_flat_dan_apartemen_112023
# pred_done
# loan_lainnya_112023
# pred_done
# loan_rumah_tinggal_112023
# pred_done
# loan_ruko_rukan_112023
# pred_done
#          total_pnddk  jmlh_kk  luas_wilayah_gis  luas_wil_dukcapil  \
# bps_kec
# 1101010         9488     2719        231.590978              213.0
# 1101020        27743     7727        180.427496              164.0
# 1101021         8139     2465        165.043407              164.0
# 1101022         6826     2082         61.142501               62.0
# 1101030         7581     2249        246.236413              252.0
#
#          pnddk_per_m  usia_20sd24  usia_25sd29  usia_30sd34  usia_35sd39  \
# bps_kec
# 1101010    40.968781         1025          804          643          726
# 1101020   153.762595         2408         2036         1953         2317
# 1101021    49.314300          813          682          582          582
# 1101022   111.640836          598          518          508          564
# 1101030    30.787486          666          555          572          551
#
#          usia_40sd44  ...  pred_loan_konstruksi_112023  \
# bps_kec               ...
# 1101010          697  ...                 37886.628265
# 1101020         2319  ...                 42538.921024
# 1101021          687  ...                 37659.981506
# 1101022          608  ...                 37439.247356
# 1101030          532  ...                 37445.002670
#
#          pred_loan_pengadaan_air_pengelolaan_sampah_limbah_daur_ulang_112023  \
# bps_kec
# 1101010                                        -462.178516
# 1101020                                        -845.175508
# 1101021                                        -423.523841
# 1101022                                        -396.992747
# 1101030                                        -423.124172
#
#          pred_loan_pengadaan_listrik_dan_gas_112023  \
# bps_kec
# 1101010                                59608.957879
# 1101020                                67152.032127
# 1101021                                58917.313715
# 1101022                                58206.005820
# 1101030                                58810.339792
#
#          pred_loan_jasa_pendidikan_112023  \
# bps_kec
# 1101010                        582.350497
# 1101020                        735.291521
# 1101021                        662.195503
# 1101022                        779.376709
# 1101030                        721.192824
#
#          pred_loan_adm_pemerintahan_pertahanan_jaminan_sosial_wajib_112023  \
# bps_kec
# 1101010                                        5709.818695
# 1101020                                        3905.405867
# 1101021                                        5751.141464
# 1101022                                        5793.345831
# 1101030                                        5775.331334
#
#          pred_loan_kendaraan_bermotor_112023  \
# bps_kec
# 1101010                         12939.912196
# 1101020                         14598.065885
# 1101021                         12845.865308
# 1101022                         12736.773338
# 1101030                         12810.381290
#
#          pred_loan_flat_dan_apartemen_112023  pred_loan_lainnya_112023  \
# bps_kec
# 1101010                         -2598.719551             240215.643072
# 1101020                         -2046.047754             286754.305203
# 1101021                         -2633.374339             236628.087712
# 1101022                         -2656.754393             233155.010090
# 1101030                         -2654.458437             235758.811712
#
#          pred_loan_rumah_tinggal_112023  pred_loan_ruko_rukan_112023
# bps_kec
# 1101010                    30204.774527                  3659.292160
# 1101020                    29879.337877                  2811.777981
# 1101021                    30698.200659                  3748.971000
# 1101022                    31148.814136                  3828.177399
# 1101030                    30602.829850                  3786.772006
#
# [5 rows x 65 columns]

# %%
x.to_excel("data_kecamatan_bi_hackaton.xlsx")

# %%
df_kec.to_excel("data_kecamatan_train.xlsx")
